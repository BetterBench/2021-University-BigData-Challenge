# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# # 1 加载数据

# %%
all_data = pd.read_excel('./data/附件1：赛题A数据.xlsx',sheet_name='比赛数据-脱敏')

# %%
list(all_data.columns)

# %%
all_data = all_data.rename(columns={'时间': 'time', '小区内的平均用户数': 'avg_user', '小区PDCP层所接收到的上行数据的总吞吐量比特': 'upward_throughput',
                           '小区PDCP层所发送的下行数据的总吞吐量比特': 'downward_throughput', '平均激活用户数': 'avg_activate_users'})

# %%
all_data['throughput'] = all_data['upward_throughput'] + all_data['downward_throughput']
data_KPI = all_data[['time', 'avg_user', 'throughput', 'avg_activate_users']]
data_KPI.head()
# Out:
#                time  avg_user   throughput  avg_activate_users
# 0  2021-08-28 00:00   22.6341  32161243768              2.7893
# 1  2021-08-28 00:00   19.1064  17015521760              3.9198
# 2  2021-08-28 00:00   15.4729   8961952016              3.1944
# 3  2021-08-28 00:00    0.0509       343112              0.0004
# 4  2021-08-28 00:00    0.6355     39529280              0.0263

# %%
list(all_data.columns)

# %%
len(list(data_KPI.columns))

# %%
all_data.head()

# %%
data_KPI.describe()

# %%
data_KPI.info()

# %%
data_KPI.isnull().sum()

# %% [markdown]
# # 平均用户数

# %%
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import matplotlib as mpl
import seaborn as sns
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

plt.plot(
    data_KPI.time,
    data_KPI.avg_user,
    label='avg_user'
)
x_major_locator = MultipleLocator(24)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xticks(rotation=25)
plt.legend()

# %% [markdown]
# # 总吞吐量

# %%
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import matplotlib as mpl
import seaborn as sns
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

plt.plot(
    data_KPI.time,
    data_KPI.throughput,
    label='throughput'
)
x_major_locator = MultipleLocator(24)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xticks(rotation=25)
plt.legend()

# %% [markdown]
# # 平均激活用户数

# %%
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import matplotlib as mpl
import seaborn as sns
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

plt.plot(
    data_KPI.time,
    data_KPI.avg_activate_users,
    label='avg_activate_users'
)
x_major_locator = MultipleLocator(24)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.xticks(rotation=25)
plt.legend()

# %%
plt.savefig("users.pdf")

# %%
plt.savefig('avg_users.jpg')
